# %% [markdown]
# <a href="https://colab.research.google.com/github/ryaustin/future_payroll/blob/main/future_payrolls.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Let's determine all future paydates for year

# %%
from datetime import datetime, date, timedelta
import pdb


start_date = '2021-11-01'  #@param {type: "date"}
year_to_stop = 2023 #@param {type: "number"}
pay_period = "Weekly"  #@param ['Weekly', 'Bi-Weekly']

print('DEMO COMPANY PAYROLLS 2022')
print('Start Date:', start_date)

payroll_start_date = datetime.strptime(start_date, '%Y-%m-%d')
payroll_end_date = payroll_start_date

this_month = payroll_end_date.month  # initialize this_month var
current_year = payroll_start_date.year
# month = payroll_end_date.month

year = 0
days_to_add = 14 if pay_period == 'Bi-Weekly' else 7
payroll_run_count = 1
nib_contribution_count_total = 0
pay_period_multiplier = 1 if pay_period == 'Weekly' else 2
# print(f'#{payroll_run_count}: start: {payroll_start_date.strftime("%d-%m-%Y")} - end: {payroll_end_date.strftime("%d-%m-%Y")}')
payroll_end_date += timedelta(days=days_to_add)
# payroll_start_date = payroll_end_date + timedelta(days=1)

while year != year_to_stop:
  monday_count = 0
  month = this_month
  print()
  print(f'Month # {payroll_end_date.strftime("%B %Y")}')
  nib_contribution_count = 0
  payrolls_ran_this_month = 0
  while this_month == month:
      for d_ord in range(payroll_start_date.toordinal(), payroll_end_date.toordinal()+1):
        d = date.fromordinal(d_ord)
        # print(d)
        # print(d.weekday)
        if (d.weekday() == 1):
            monday_count += 1
      print(f'#{payroll_run_count}: start: {payroll_start_date.strftime("%d-%m-%Y")} - end: {payroll_end_date.strftime("%d-%m-%Y")}')
      payroll_start_date = payroll_end_date + timedelta(days=1)
      payroll_end_date += timedelta(days=days_to_add)
      year = payroll_end_date.year
      payroll_run_count += 1
      payrolls_ran_this_month +=1
      next_pay = payroll_end_date + timedelta(days=days_to_add)
      # pdb.set_trace()
      this_month = payroll_end_date.month
      if not this_month == month:
        nib_contribution_count = payrolls_ran_this_month * pay_period_multiplier
        nib_contribution_count_total += nib_contribution_count
        print(f'-- {payrolls_ran_this_month} Payrolls & {nib_contribution_count} NIB Contributions this month -- {nib_contribution_count_total} Total NIB Contributions')
        print({monday_count}, 'Mondays captured')
# Out:
# DEMO COMPANY PAYROLLS 2022
# Start Date: 2021-11-01
#
# Month # November 2021
# #1: start: 01-11-2021 - end: 08-11-2021
# #2: start: 09-11-2021 - end: 15-11-2021
# #3: start: 16-11-2021 - end: 22-11-2021
# #4: start: 23-11-2021 - end: 29-11-2021
# -- 4 Payrolls & 4 NIB Contributions this month -- 4 Total NIB Contributions
# {4} Mondays captured
#
# Month # December 2021
# #5: start: 30-11-2021 - end: 06-12-2021
# #6: start: 07-12-2021 - end: 13-12-2021
# #7: start: 14-12-2021 - end: 20-12-2021
# #8: start: 21-12-2021 - end: 27-12-2021
# -- 4 Payrolls & 4 NIB Contributions this month -- 8 Total NIB Contributions
# {4} Mondays captured
#
# Month # January 2022
# #9: start: 28-12-2021 - end: 03-01-2022
# #10: start: 04-01-2022 - end: 10-01-2022
# #11: start: 11-01-2022 - end: 17-01-2022
# #12: start: 18-01-2022 - end: 24-01-2022
# #13: start: 25-01-2022 - end: 31-01-2022
# -- 5 Payrolls & 5 NIB Contributions this month -- 13 Total NIB Contributions
# {5} Mondays captured
#
# Month # February 2022
# #14: start: 01-02-2022 - end: 07-02-2022
# #15: start: 08-02-2022 - end: 14-02-2022
# #16: start: 15-02-2022 - end: 21-02-2022
# #17: start: 22-02-2022 - end: 28-02-2022
# -- 4 Payrolls & 4 NIB Contributions this month -- 17 Total NIB Contributions
# {4} Mondays captured
#
# Month # March 2022
# #18: start: 01-03-2022 - end: 07-03-2022
# #19: start: 08-03-2022 - end: 14-03-2022
# #20: start: 15-03-2022 - end: 21-03-2022
# #21: start: 22-03-2022 - end: 28-03-2022
# -- 4 Payrolls & 4 NIB Contributions this month -- 21 Total NIB Contributions
# {4} Mondays captured
#
# Month # April 2022
# #22: start: 29-03-2022 - end: 04-04-2022
# #23: start: 05-04-2022 - end: 11-04-2022
# #24: start: 12-04-2022 - end: 18-04-2022
# #25: start: 19-04-2022 - end: 25-04-2022
# -- 4 Payrolls & 4 NIB Contributions this month -- 25 Total NIB Contributions
# {4} Mondays captured
#
# Month # May 2022
# #26: start: 26-04-2022 - end: 02-05-2022
# #27: start: 03-05-2022 - end: 09-05-2022
# #28: start: 10-05-2022 - end: 16-05-2022
# #29: start: 17-05-2022 - end: 23-05-2022
# #30: start: 24-05-2022 - end: 30-05-2022
# -- 5 Payrolls & 5 NIB Contributions this month -- 30 Total NIB Contributions
# {5} Mondays captured
#
# Month # June 2022
# #31: start: 31-05-2022 - end: 06-06-2022
# #32: start: 07-06-2022 - end: 13-06-2022
# #33: start: 14-06-2022 - end: 20-06-2022
# #34: start: 21-06-2022 - end: 27-06-2022
# -- 4 Payrolls & 4 NIB Contributions this month -- 34 Total NIB Contributions
# {4} Mondays captured
#
# Month # July 2022
# #35: start: 28-06-2022 - end: 04-07-2022
# #36: start: 05-07-2022 - end: 11-07-2022
# #37: start: 12-07-2022 - end: 18-07-2022
# #38: start: 19-07-2022 - end: 25-07-2022
# -- 4 Payrolls & 4 NIB Contributions this month -- 38 Total NIB Contributions
# {4} Mondays captured
#
# Month # August 2022
# #39: start: 26-07-2022 - end: 01-08-2022
# #40: start: 02-08-2022 - end: 08-08-2022
# #41: start: 09-08-2022 - end: 15-08-2022
# #42: start: 16-08-2022 - end: 22-08-2022
# #43: start: 23-08-2022 - end: 29-08-2022
# -- 5 Payrolls & 5 NIB Contributions this month -- 43 Total NIB Contributions
# {5} Mondays captured
#
# Month # September 2022
# #44: start: 30-08-2022 - end: 05-09-2022
# #45: start: 06-09-2022 - end: 12-09-2022
# #46: start: 13-09-2022 - end: 19-09-2022
# #47: start: 20-09-2022 - end: 26-09-2022
# -- 4 Payrolls & 4 NIB Contributions this month -- 47 Total NIB Contributions
# {4} Mondays captured
#
# Month # October 2022
# #48: start: 27-09-2022 - end: 03-10-2022
# #49: start: 04-10-2022 - end: 10-10-2022
# #50: start: 11-10-2022 - end: 17-10-2022
# #51: start: 18-10-2022 - end: 24-10-2022
# #52: start: 25-10-2022 - end: 31-10-2022
# -- 5 Payrolls & 5 NIB Contributions this month -- 52 Total NIB Contributions
# {5} Mondays captured
#
# Month # November 2022
# #53: start: 01-11-2022 - end: 07-11-2022
# #54: start: 08-11-2022 - end: 14-11-2022
# #55: start: 15-11-2022 - end: 21-11-2022
# #56: start: 22-11-2022 - end: 28-11-2022
# -- 4 Payrolls & 4 NIB Contributions this month -- 56 Total NIB Contributions
# {4} Mondays captured
#
# Month # December 2022
# #57: start: 29-11-2022 - end: 05-12-2022
# #58: start: 06-12-2022 - end: 12-12-2022
# #59: start: 13-12-2022 - end: 19-12-2022
# #60: start: 20-12-2022 - end: 26-12-2022
# -- 4 Payrolls & 4 NIB Contributions this month -- 60 Total NIB Contributions
# {4} Mondays captured
